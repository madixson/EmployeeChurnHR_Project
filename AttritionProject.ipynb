# %% [markdown]
# <a href="https://colab.research.google.com/github/madixson/EmployeeAttritionHR_Project/blob/main/AttritionProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Employee Churn

# %%
#the basics
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

#sklearn
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

#RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import plot_tree

#Bayes
from sklearn.naive_bayes import GaussianNB

# Logistic Regression
from sklearn.linear_model import LogisticRegression

# NN
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # ------------------Cleaning------------------

# %%
df_raw = pd.read_csv('/content/drive/MyDrive/HR_AttritionProject/EmployeeData.csv', encoding='ISO-8859-1')
df_raw.head()
# Out:
#         stag  event gender   age         industry  profession      traffic  \
# 0   7.030801      1      m  35.0            Banks          HR  rabrecNErab
# 1  22.965092      1      m  33.0            Banks          HR        empjs
# 2  15.934292      1      f  35.0  PowerGeneration          HR  rabrecNErab
# 3  15.934292      1      f  35.0  PowerGeneration          HR  rabrecNErab
# 4   8.410678      1      m  32.0           Retail  Commercial        youjs
#
#   coach head_gender greywage  way  extraversion  independ  selfcontrol  \
# 0    no           f    white  bus           6.2       4.1          5.7
# 1    no           m    white  bus           6.2       4.1          5.7
# 2    no           m    white  bus           6.2       6.2          2.6
# 3    no           m    white  bus           5.4       7.6          4.9
# 4   yes           f    white  bus           3.0       4.1          8.0
#
#    anxiety  novator
# 0      7.1      8.3
# 1      7.1      8.3
# 2      4.8      8.3
# 3      2.5      6.7
# 4      7.1      3.7

# %% [markdown]
# ## Check & Remove any Null Values

# %%
df = df_raw.dropna()

# %% [markdown]
# #### There are no null values to remove

# %% [markdown]
# ## Check and Remove Outliers

# %%
def plot_boxplot(df, feature):
    print(feature)
    df.boxplot(column=[feature])
    plt.grid(False)
    plt.show()

# %%
#boxplots for all of our numerical values
plot_boxplot(df, 'satisfaction_level')
plot_boxplot(df, 'last_evaluation')
plot_boxplot(df, 'number_project')
plot_boxplot(df, 'average_montly_hours')
plot_boxplot(df, 'time_spend_company')
# Out:
# satisfaction_level
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-436eb9a2bcc4> in <cell line: 2>()
#       1 #boxplots for all of our numerical values
# ----> 2 plot_boxplot(df, 'satisfaction_level')
#       3 plot_boxplot(df, 'last_evaluation')
#       4 plot_boxplot(df, 'number_project')
#       5 plot_boxplot(df, 'average_montly_hours')
#
# <ipython-input-18-a8adce103bbb> in plot_boxplot(df, feature)
#       1 def plot_boxplot(df, feature):
#       2     print(feature)
# ----> 3     df.boxplot(column=[feature])
#       4     plt.grid(False)
#       5     plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     456     import matplotlib.pyplot as plt
#     457
# --> 458     ax = boxplot(
#     459         self,
#     460         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     433             columns = data.columns
#     434         else:
# --> 435             data = data[columns]
#     436
#     437         result = plot_group(columns, data.values.T, ax, **kwds)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['satisfaction_level'], dtype='object')] are in the [columns]"

# %% [markdown]
# #### Overall I feel the outliers present in 'time_spend_company' were relevant ans should stay in the data for us to analyze

# %% [markdown]
# ### Change categorical to numerical

# %%
#Encode categotical variable
datacat = df.select_dtypes(exclude=["number"])
LE=LabelEncoder()
for i in datacat:
    df[i]=df[[i]].apply(LE.fit_transform)

# %%
orig = df
target = df['left']
df = df.drop(['left'], axis =1)

# %%
#This is the numerical dataset
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years  sales  salary
# 0                   3              0                      0      7       1
# 1                   6              0                      0      7       2
# 2                   4              0                      0      7       2
# 3                   5              0                      0      7       1
# 4                   3              0                      0      7       1

# %% [markdown]
#  # ----------------------------EDA----------------------------

# %%
#color palette
pal = ['#0f39f7', '#fcf00a']
b = '#0f39f7'
y = '#fcf00a'

# %%
list(orig.columns)
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'sales',
#  'salary']

# %%
orig.shape
# Out:
# (14999, 10)

# %%
orig.replace((1, 0), ('left', 'stayed'), inplace=True)

# %%
orig['left'].value_counts().plot.pie( colors = pal)
plt.show()

# %%
orig.replace(('left', 'stayed'), (1,0), inplace=True)
g = orig.groupby(['left'])
c1 = g.get_group(1)
c2 = g.get_group(0)

# %%
def compare(df, ft):
    sns.distplot(c1[ft], color = y, hist=False)
    sns.distplot(c2[ft], color = b, hist=False)
    plt.legend(labels=["left","stayed"])
    plt.show()

# %%
for feature in orig:
    compare(orig, feature)
# Out:
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c1[ft], color = y, hist=False)
# /var/folders/6n/x3652qj92pv8yrnwqytnq3d40000gn/T/ipykernel_14257/1784404461.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c2[ft], color = b, hist=False)

# %% [markdown]
# ## Correlation

# %%
corrmat= orig.corr()
plt.figure(figsize=(10,10))  
sns.heatmap(corrmat,annot=True,cmap = 'GnBu', center=0)
plt.show()

# %% [markdown]
# # -----------------------MODELS-----------------------

# %% [markdown]
# ### Prepping for models

# %%
#Label predictive variable and remove from orig dataset & convert to np array
y = np.array(target)
X = np.array(df)
feature_list = list(df.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 2, metric = 'euclidean')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=2)

# %%
y_pred = knn.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3371   63]
#  [  87  979]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3434
#            1       0.94      0.92      0.93      1066
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.95      0.95      4500
# weighted avg       0.97      0.97      0.97      4500

# %% [markdown]
# ## Random Forest

# %%
# random forest model creation
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# predictions
rfc_predict = rfc.predict(X_test)

# %%
rfc_cv_score = cross_val_score(rfc, X, y, cv=10, scoring='roc_auc')

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3371   63]
#  [  87  979]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3434
#            1       0.94      0.92      0.93      1066
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.95      0.95      4500
# weighted avg       0.97      0.97      0.97      4500

# %%
plt.figure(figsize=(60,40))
plot_tree(rfc.estimators_[5], feature_names = orig.columns,class_names=['left', "stayed"],filled=True);
plt.show()

# %%
# Get numerical feature importances
importances = list(rfc.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

[print('Variable: {:19} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: satisfaction_level  Importance: 0.35
# Variable: time_spend_company  Importance: 0.19
# Variable: number_project      Importance: 0.16
# Variable: average_montly_hours Importance: 0.15
# Variable: last_evaluation     Importance: 0.12
# Variable: Work_accident       Importance: 0.01
# Variable: sales               Importance: 0.01
# Variable: salary              Importance: 0.01
# Variable: promotion_last_5years Importance: 0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.bar(x_values, importances, orientation = 'vertical')
plt.xticks(x_values, feature_list, rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# ## Naive Bayes

# %%
GNB = GaussianNB()
GNB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = GNB.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[2819  629]
#  [ 294  758]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86      3448
#            1       0.55      0.72      0.62      1052
#
#     accuracy                           0.79      4500
#    macro avg       0.73      0.77      0.74      4500
# weighted avg       0.82      0.79      0.80      4500

# %% [markdown]
# ## Logisitic Regression

# %%
# logistic regression model creation
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)

# predictions
lr_predict = lr.predict(X_test)

# evaluation
print(confusion_matrix(y_test, lr_predict))
print(classification_report(y_test, lr_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e11f91151111> in <cell line: 3>()
#       1 # logistic regression model creation
#       2 lr = LogisticRegression(max_iter=1000)
# ----> 3 lr.fit(X_train, y_train)
#       4
#       5 # predictions
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ## Neural Networks

# %%
# neural network model creation
nn = Sequential()
nn.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
nn.add(Dense(32, activation='relu'))
nn.add(Dense(1, activation='sigmoid'))
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the model
nn.fit(X_train, y_train, epochs=50, batch_size=32, verbose=0)

# predictions
nn_predict = nn.predict_classes(X_test)

# evaluation
print(confusion_matrix(y_test, nn_predict))
print(classification_report(y_test, nn_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-220d1e4b1e9a> in <cell line: 3>()
#       1 # neural network model creation
#       2 nn = Sequential()
# ----> 3 nn.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
#       4 nn.add(Dense(32, activation='relu'))
#       5 nn.add(Dense(1, activation='sigmoid'))
#
# NameError: name 'X_train' is not defined
